# %% [markdown]
# Import potrzebnych bibliotek

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# Analiza produkcji kawy

# %%
# Pobieramy cały dataset z produkcji
production = pd.read_csv('../coffee-datasets/Coffee_production.csv')
production
# Out:
#                              Country      Coffee type       1990/91  \
# 0                             Angola  Robusta/Arabica  3.000000e+06
# 1                            Bolivia          Arabica  7.380000e+06
# 2                             Brazil  Arabica/Robusta  1.637160e+09
# 3                            Burundi  Arabica/Robusta  2.922000e+07
# 4                            Ecuador  Arabica/Robusta  9.024000e+07
# 5                          Indonesia  Robusta/Arabica  4.464600e+08
# 6                         Madagascar          Robusta  5.892000e+07
# 7                             Malawi          Arabica  6.300000e+06
# 8                   Papua New Guinea  Arabica/Robusta  5.778000e+07
# 9                           Paraguay          Arabica  7.860000e+06
# 10                              Peru          Arabica  5.622000e+07
# 11                            Rwanda          Arabica  3.210000e+07
# 12                       Timor-Leste          Arabica  0.000000e+00
# ...

# %%
# Pobieramy cały dataset z coffee yields czyli wydajność ziaren kawy mierzona w tonach na hektar
coffee_yields = pd.read_csv('../coffee-datasets/Coffee-yields.csv')
# My zajmujemy się latami 1990-2020 więc filtruję żeby tylko takie tu się znajdowały
coffee_yields = coffee_yields[(coffee_yields['Year'] > 1989) & (coffee_yields['Year'] < 2021)]
coffee_yields.rename(columns={coffee_yields.columns[3]: 'Tonnes per hectare'}, inplace=True)
coffee_yields
# Out:
#         Entity Code  Year  Tonnes per hectare
# 29      Africa  NaN  1990            0.386624
# 30      Africa  NaN  1991            0.402463
# 31      Africa  NaN  1992            0.427469
# 32      Africa  NaN  1993            0.369922
# 33      Africa  NaN  1994            0.440736
# ...        ...  ...   ...                 ...
# 6685  Zimbabwe  ZWE  2016            0.250000
# 6686  Zimbabwe  ZWE  2017            0.250000
# 6687  Zimbabwe  ZWE  2018            0.250000
# 6688  Zimbabwe  ZWE  2019            0.250000
# 6689  Zimbabwe  ZWE  2020            0.250000
#
# [3413 rows x 4 columns]

# %%
# Pobieramy cały dataset z coffee production map dla wizualizacji na mapie
coffe_prod_world = pd.read_csv('../coffee-datasets/Coffe-bean-production-world.csv')
# My zajmujemy się latami 1990-2020 więc filtruję żeby tylko takie tu się znajdowały
coffe_prod_world = coffe_prod_world[(coffe_prod_world['Year'] > 1989) & (coffe_prod_world['Year'] < 2021)]
coffe_prod_world.rename(columns={coffe_prod_world.columns[3]: 'Tonnes'}, inplace=True)
coffe_prod_world
# Out:
#         Entity Code  Year      Tonnes
# 29      Africa  NaN  1990  1254209.00
# 30      Africa  NaN  1991  1192734.00
# 31      Africa  NaN  1992  1156200.00
# 32      Africa  NaN  1993   991822.56
# 33      Africa  NaN  1994  1058407.90
# ...        ...  ...   ...         ...
# 7090  Zimbabwe  ZWE  2016      700.00
# 7091  Zimbabwe  ZWE  2017      683.33
# 7092  Zimbabwe  ZWE  2018      627.78
# 7093  Zimbabwe  ZWE  2019      670.37
# 7094  Zimbabwe  ZWE  2020      660.49
#
# [3641 rows x 4 columns]

# %%
# lista krajów i typów kaw dla których robimy wizualizację danych
countries = production['Country']
coffe_types = production['Coffee type'].unique()

countries, coffe_types
# Out:
# (0                               Angola
#  1                              Bolivia
#  2                               Brazil
#  3                              Burundi
#  4                              Ecuador
#  5                            Indonesia
#  6                           Madagascar
#  7                               Malawi
#  8                     Papua New Guinea
#  9                             Paraguay
#  10                                Peru
#  11                              Rwanda
#  12                         Timor-Leste
#  13                            Zimbabwe
#  14                               Congo
#  15                                Cuba
#  16                  Dominican Republic
#  17                               Haiti
#  18                         Philippines
#  19                            Tanzania
#  20                              Zambia
#  21                            Cameroon
#  22            Central African Republic
# ...

# %%
# Całkowita produkcja malejąco (top 10)
top_production = production[['Country', 'Total_production']].sort_values(by=['Total_production'], ascending=False).head(10)

# Tutaj wyświetlam Total_production w zwykłej notacji, nie eksponencjalnej
top_ten_producers = pd.concat([top_production['Country'], top_production['Total_production'].apply(lambda x: '{:,.0f}'.format(x))], axis=1).rename(columns={'Total_production': 'Total production'})
top_ten_producers
# Out:
#       Country Total production
# 2      Brazil   75,082,980,000
# 53    Vietnam   28,803,180,000
# 23   Colombia   21,598,620,000
# 5   Indonesia   15,404,880,000
# 29   Ethiopia    8,669,520,000
# 36      India    8,222,220,000
# 41     Mexico    7,853,520,000
# 32  Guatemala    7,020,540,000
# 35   Honduras    6,672,720,000
# 51     Uganda    5,919,480,000

# %%
# Pierwszy wykres - top 10 producentów kawy na świecie
fig = px.bar(top_production, x='Country', y='Total_production', labels={
    "Country": "Countries",
    "Total_production": "Total Production (kg)"
}, title='Top 10 Countries with the Highest Coffee Production:', width=1200, height=800, color_discrete_sequence=['#78533d'])

fig.update_layout(
    yaxis=dict(title='Total Production (kg)'),
    annotations=[
        dict(
            text='(B = Billions)',
            showarrow=False,
            xref='paper',
            yref='y',
            x=1.0,
            y=max(top_production['Total_production']) * 0.95,
            font=dict(size=17)
        )
    ]
)

fig.show()
# Out:
# <div>                            <div id="1a7edcbe-9e24-4cf9-8d67-ca6adf08d48d" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a7edcbe-9e24-4cf9-8d67-ca6adf08d48d")) {                    Plotly.newPlot(                        "1a7edcbe-9e24-4cf9-8d67-ca6adf08d48d",                        [{"alignmentgroup":"True","hovertemplate":"Countries=%{x}\u003cbr\u003eTotal Production (kg)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#78533d","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Brazil","Vietnam","Colombia","Indonesia","Ethiopia","India","Mexico","Guatemala","Honduras","Uganda"],"xaxis":"x","y":[75082980000.0,28803180000.0,21598620000.0,15404
# ...

# %%
# Drugi wykres - średnia produkcja kawy na przeestrzeni lat 1990-2020
df = coffe_prod_world.copy()  # Skopiowanie oryginalnego DataFrame
df['Kilograms'] = df['Tonnes'] * 1000 # zamiana na kilogramy
df['Kilograms'] = df['Kilograms'].astype(float)  # Konwersja kolumny Tonnes per hectare na float

# Obliczanie średniej ilości ton na hektar dla każdego kraju
df_avg = df.groupby(['Entity', 'Code'])['Kilograms'].mean().reset_index()

# Tworzenie wizualizacji na mapie
fig = px.choropleth(df_avg, locations='Code', locationmode='ISO-3', color='Kilograms',
                    title='Average Coffee Production by Country (1990-2020)',
                    color_continuous_scale='Turbid',
                    hover_name='Entity',
                    hover_data=['Kilograms'],
                    labels={'Kilograms': 'Kilograms'},
                    height=800,
                    range_color=(0, df_avg['Kilograms'].max()))  # Zakres kolorów

fig.update_layout(geo=dict(showframe=False, showcoastlines=False, projection_type='equirectangular'))

# Ustawienie koloru i konturów dla krajów bez danych
fig.update_geos(
    visible=False,
    showcountries=True,
    countrycolor="white",
    showsubunits=True,
    subunitcolor="white",
    subunitwidth=0.5
)

# Wyświetlanie wykresu
fig.show()
# Out:
# <div>                            <div id="f627b547-e036-4151-abc9-9237e684b40f" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f627b547-e036-4151-abc9-9237e684b40f")) {                    Plotly.newPlot(                        "f627b547-e036-4151-abc9-9237e684b40f",                        [{"coloraxis":"coloraxis","customdata":[[7431493.225806451],[87221.0],[107455.48387096774],[23410270.967741936],[2249542612.903226],[47444466.451612905],[301184.8387096774],[60727618.70967742],[20171.612903225807],[9306721.290322581],[47081040.96774194],[724097193.548387],[113884.51612903226],[2305461.290322581],[3660.3225806451615],[120338785.80645162],[175101370.0],[12995590.967741935],[50005884.19354839],[306784.8387096774],[32841805.48387097],[9896870.32258064
# ...

# %%
# przygotowanie danych pod top 20 producentów kaw wzgledem typu kawy
top_production = production[['Country', 'Total_production', 'Coffee type']].sort_values(by=['Total_production'], ascending=False).head(20)
top_production
# Out:
#              Country  Total_production      Coffee type
# 2             Brazil      7.508298e+10  Arabica/Robusta
# 53           Vietnam      2.880318e+10  Robusta/Arabica
# 23          Colombia      2.159862e+10          Arabica
# 5          Indonesia      1.540488e+10  Robusta/Arabica
# 29          Ethiopia      8.669520e+09          Arabica
# 36             India      8.222220e+09  Robusta/Arabica
# 41            Mexico      7.853520e+09  Arabica/Robusta
# 32         Guatemala      7.020540e+09  Arabica/Robusta
# 35          Honduras      6.672720e+09          Arabica
# 51            Uganda      5.919480e+09  Robusta/Arabica
# 10              Peru      5.317620e+09          Arabica
# 25     Côte d'Ivoire      4.761420e+09          Robusta
# 24        Costa Rica      3.596700e+09          Arabica
# 27       El Salvador      2.820900e+09          Arabica
# 43         Nicaragua      2.749380e+09          Arabica
# 52         Venezuela      1.992780e+09          Arabica
# ...

# %%
# trzeci wykres - Top 20 producentów kawy na świecie wzgledem typu kawy
fig = px.bar(top_production, x='Country', y='Total_production', color='Coffee type', labels={
    "Country": "Countries",
    "Total_production": "Total Production"
},title='Top 20 Countries with Highest Coffee Production according to Coffee type', width=1000, height=600)

fig.update_layout(
    xaxis_title="Countries",
    yaxis_title="Total Production",
    title="Top 20 Countries with Highest Coffee Production according to Coffee type",
    width=1200,
    height=800,
    barmode='stack',
    yaxis=dict(title='Total Production (kg)'),
    annotations=[
        dict(
            text='(B = Billions)',
            showarrow=False,
            xref='paper',
            yref='y',
            x=1.0,
            y=max(top_production['Total_production']) * 0.95,
            font=dict(size=17)
        )
    ]
)
fig.show()
# Out:
# <div>                            <div id="bde09976-022c-4768-a110-d36dbdb32321" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bde09976-022c-4768-a110-d36dbdb32321")) {                    Plotly.newPlot(                        "bde09976-022c-4768-a110-d36dbdb32321",                        [{"alignmentgroup":"True","hovertemplate":"Coffee type=Arabica\u002fRobusta\u003cbr\u003eCountries=%{x}\u003cbr\u003eTotal Production=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Arabica\u002fRobusta","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Arabica\u002fRobusta","offsetgroup":"Arabica\u002fRobusta","orientation":"v","showlegend":true,"textposition":"auto","x":["Brazil","Mexico","Guatemala","Ecuador","Papua New Guinea"],"xaxis"
# ...

# %%
# porozdzielamy sobie teraz każdy typ kawy
sorted_production = production[['Country', 'Total_production', 'Coffee type']].sort_values(by=['Total_production'], ascending=False)
robusta = sorted_production[sorted_production['Coffee type'] == 'Robusta']
arabica = sorted_production[sorted_production['Coffee type'] == 'Arabica']
arabica_robusta = sorted_production[sorted_production['Coffee type'] == 'Arabica/Robusta']
robusta_arabica = sorted_production[sorted_production['Coffee type'] == 'Robusta/Arabica']

# %%
# Czwarty wykres - Produkcja kawy podzielona na coffee type - wykres Treemap
fig = go.Figure()

# Definiowanie palety kolorów
colors = ["#78533d", "#8a6347", "#9e7352", "#b1845e", "#c5976b", "#d7aa79", "#e9be88", "#f4d2a0", "#f8e8c1", "#fdf3e3"]


# Dodawanie treemap dla Robusty
fig.add_trace(
    go.Treemap(
        labels=robusta.head(10).Country,
        parents=["Robusta"] * 10,
        values=robusta.Total_production,
        name="Robusta",
        text=robusta.Total_production.apply(lambda x: f"{x:,.2f}"),
        textinfo="text+label",
        domain=dict(x=[0, 0.45], y=[0.5, 1]),
        marker=dict(colors=colors),
        hovertemplate='<b>%{label}</b><br>Total Production: %{value:,.2f}<br>'
    )
)

# Dodawanie treemap dla Arabiki
fig.add_trace(
    go.Treemap(
        labels=arabica.head(10).Country,
        parents=["Arabica"] * 10,
        values=arabica.Total_production,
        name="Arabica",
        text=arabica.Total_production.apply(lambda x: f"{x:,.2f}"),
        textinfo="text+label",
        domain=dict(x=[0.55, 1], y=[0.5, 1]),
        marker=dict(colors=colors),
        hovertemplate='<b>%{label}</b><br>Total Production: %{value:,.2f}<br>'
    )
)

# Dodawanie treemap dla Arabiki/Robusty
fig.add_trace(
    go.Treemap(
        labels=arabica_robusta.head(10).Country,
        parents=["Arabica/Robusta"] * 10,
        values=arabica_robusta.Total_production,
        name="Arabica/Robusta",
        text=arabica_robusta.Total_production.apply(lambda x: f"{x:,.2f}"),
        textinfo="text+label",
        domain=dict(x=[0, 0.45], y=[0, 0.4]),
        marker=dict(colors=colors),
        hovertemplate='<b>%{label}</b><br>Total Production: %{value:,.2f}<br>'
    )
)

# Dodawanie treemap dla Robusty/Arabiki
fig.add_trace(
    go.Treemap(
        labels=robusta_arabica.head(10).Country,
        parents=["Robusta/Arabica"] * 10,
        values=robusta_arabica.Total_production,
        name="Robusta/Arabica",
        text=robusta_arabica.Total_production.apply(lambda x: f"{x:,.2f}"),
        textinfo="text+label",
        domain=dict(x=[0.55, 1], y=[0, 0.4]),
        marker=dict(colors=colors),
        hovertemplate='<b>%{label}</b><br>Total Production: %{value:,.2f}<br>'
    )
)

# Aktualizowanie układu i wyświetlanie zdjęcia
fig.update_layout(height=1200, width=1200, title_text="Coffee Production by Type")
fig.show()
# Out:
# <div>                            <div id="d6d16fc9-f9d5-43f3-b7f6-1c3bf3169d32" class="plotly-graph-div" style="height:1200px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6d16fc9-f9d5-43f3-b7f6-1c3bf3169d32")) {                    Plotly.newPlot(                        "d6d16fc9-f9d5-43f3-b7f6-1c3bf3169d32",                        [{"domain":{"x":[0,0.45],"y":[0.5,1]},"hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003eTotal Production: %{value:,.2f}\u003cbr\u003e","labels":["C\u00f4te d'Ivoire","Madagascar","Lao People's Democratic Republic","Guinea","Togo","Central African Republic","Sierra Leone","Nigeria","Ghana","Trinidad & Tobago"],"marker":{"colors":["#78533d","#8a6347","#9e7352","#b1845e","#c5976b","#d7aa79","#e9be88","#f4d2a0","#f8e8c1","#fdf3e3"]},"name":"Rob
# ...

# %%
# Tutaj przygotowuje dfa pod wykres w którym pokażemy produkcje w top 5 krajach na przestrzeni lat 1990-2020
top_production_helper = production[['Country', 'Total_production']].sort_values(by=['Total_production'], ascending=False).head(5)
top_production_by_years = production[production.Country.isin(top_production_helper['Country'].unique())]
top_production_by_years = top_production_by_years.T
top_production_by_years.drop(['Country', 'Total_production', 'Coffee type'], axis=0, inplace=True)
top_production_by_years.index.name = 'Year'
top_production_by_years.columns = top_production_helper['Country'].values
top_production_by_years
# Out:
#                Brazil      Vietnam      Colombia    Indonesia      Ethiopia
# Year
# 1990/91  1637160000.0  446460000.0   863760000.0  174540000.0    78600000.0
# 1991/92  1637580000.0  509580000.0  1078800000.0  175500000.0    86280000.0
# 1992/93  2076180000.0  334140000.0   896820000.0  109500000.0   140400000.0
# 1993/94  1690020000.0  404580000.0   685320000.0  178020000.0   181200000.0
# 1994/95  1691520000.0  322080000.0   777840000.0  165780000.0   217920000.0
# 1995/96  1083600000.0  274380000.0   776280000.0  189900000.0   238200000.0
# 1996/97  1751820000.0  493260000.0   646740000.0  204420000.0   345120000.0
# 1997/98  1568880000.0  457260000.0   727320000.0  183420000.0   418740000.0
# 1998/99  2205660000.0  437760000.0   652080000.0  175680000.0   423120000.0
# 1999/00  2854680000.0  393420000.0   570720000.0  227040000.0   697860000.0
# 2000/01  1878600000.0  419220000.0   631140000.0  186900000.0   890460000.0
# ...

# %%
# Piąty wykres - top 5 krajów produkcja na przestrzeni lat 1990-2020
fig = px.line(top_production_by_years,
              x=top_production_by_years.index, y=top_production_by_years.columns[0:],
              labels={"Year": "Year", "value": "Production Rate"},
              title='Production Rates of the top 5 Countries over the years 1990-2020',
              width=1200, height=800)

fig.update_layout(legend_title_text="Country",
                  annotations=[dict(text='(B = Billions)',
                                    showarrow=False,
                                    xref='paper',
                                    yref='y',
                                    x=1.0,
                                    y=max(top_production['Total_production']) * 0.06,
                                    font=dict(size=17))])

fig.show()
# Out:
# <div>                            <div id="6e30a1eb-67aa-4ea1-86e8-bed6fa94d6cb" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e30a1eb-67aa-4ea1-86e8-bed6fa94d6cb")) {                    Plotly.newPlot(                        "6e30a1eb-67aa-4ea1-86e8-bed6fa94d6cb",                        [{"hovertemplate":"variable=Brazil\u003cbr\u003eYear=%{x}\u003cbr\u003eProduction Rate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brazil","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Brazil","orientation":"v","showlegend":true,"x":["1990\u002f91","1991\u002f92","1992\u002f93","1993\u002f94","1994\u002f95","1995\u002f96","1996\u002f97","1997\u002f98","1998\u002f99","1999\u002f00","2000\u002f01","2
# ...

# %%
# Szósty wykres - wydajność kawy - ilość wyprodukowanej kawy na hektar pola - średnia z lat 1990-2020
df = coffee_yields.copy()  # Skopiowanie oryginalnego DataFrame
df['Kilograms per hectare'] = df['Tonnes per hectare'] * 1000
df['Kilograms per hectare'] = df['Kilograms per hectare'].astype(float)  # Konwersja kolumny Tonnes per hectare na float

# Obliczanie średniej ilości ton na hektar dla każdego kraju
df_avg = df.groupby(['Entity', 'Code'])['Kilograms per hectare'].mean().reset_index()

# Tworzenie wizualizacji na mapie
fig = px.choropleth(df_avg, locations='Code', locationmode='ISO-3', color='Kilograms per hectare',
                    title='Average Coffee Yields by Country (1990-2020)',
                    color_continuous_scale='Turbid',
                    hover_name='Entity',
                    hover_data=['Kilograms per hectare'],
                    labels={'Kilograms per hectare': 'Kilograms per hectare'},
                    height=800,
                    range_color=(0, df_avg['Kilograms per hectare'].max()))  # Zakres kolorów

fig.update_layout(geo=dict(showframe=False, showcoastlines=False, projection_type='equirectangular'))

# Ustawienie koloru i konturów dla krajów bez danych
fig.update_geos(
    visible=False,
    showcountries=True,
    countrycolor="white",
    showsubunits=True,
    subunitcolor="white",
    subunitwidth=0.5
)

# Wyświetlanie wykresu
fig.show()
# Out:
# <div>                            <div id="6c8ccb3e-b439-4940-9ed3-7901792dbafa" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c8ccb3e-b439-4940-9ed3-7901792dbafa")) {                    Plotly.newPlot(                        "6c8ccb3e-b439-4940-9ed3-7901792dbafa",                        [{"coloraxis":"coloraxis","customdata":[[210.3999974516129],[2044.460856521739],[189.49999548387098],[928.2161080645162],[1060.1806125806452],[899.5677316129032],[796.3128864516128],[314.1161206451613],[205.20832916666666],[445.60967],[1720.7419006451612],[882.5161232258065],[147.0774158064516],[341.75160322580643],[636.0785614285714],[1208.583845483871],[238.72580319354836],[286.8483764516129],[379.1225767741936],[663.7903116129032],[268.54193274193545],[214.6451
# ...
